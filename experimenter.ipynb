# %%
import matplotlib.pyplot as plt
import os

# %%
file1 = open("ClusterLib"+os.sep+"N3000K20.txt","r");
file2 = open("ClusterLib"+os.sep+"N5000K15DENSE.txt","r");
file3 = open("ClusterLib"+os.sep+"N5000K15SPARSE.txt","r");
file4 = open("ClusterLib"+os.sep+"N7500K50.txt","r");
file5 = open("ClusterLib"+os.sep+"N100000K100GRID.txt","r");
file6 = open("ClusterLib"+os.sep+"N100000K100RD.txt","r");

# %%
# k =
# Out:
#   File "<ipython-input-8-be8ccdcf21b6>", line 1
#     k =
#         ^
# SyntaxError: invalid syntax

# %%
x = []
y = []
for a in file1:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))


ks = [ "16" , "32" , "64" , "128"]
for k in ks:
    out = open("ClusterLib"+os.sep+"output1.txt","r");
    
    plt.plot(x, y, '.', color='blue');
    
time = float(outfile1.read().split()[0])

# %%
x = []
y = []
for a in file2:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))

plt.plot(x, y, '.', color='blue');
outfile2 = open("ClusterLib"+os.sep+"output2.txt","r");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-7800da26534f> in <module>
#       7
#       8 plt.plot(x, y, '.', color='blue');
# ----> 9 outfile2 = open("ClusterLib"+os.sep+"output2.txt","r");
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ClusterLib\\output2.txt'

# %%
x = []
y = []
for a in file3:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))

plt.plot(x, y, '.', color='blue');
outfile3 = open("ClusterLib"+os.sep+"output3.txt","r");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-dca18683acec> in <module>
#       7
#       8 plt.plot(x, y, '.', color='blue');
# ----> 9 outfile3 = open("ClusterLib"+os.sep+"output3.txt","r");
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ClusterLib\\output3.txt'

# %%
x = []
y = []
for a in file4:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))

plt.plot(x, y, '.', color='blue');
outfile4 = open("ClusterLib"+os.sep+"output4.txt","r");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-01d6df60aef4> in <module>
#       7
#       8 plt.plot(x, y, '.', color='blue');
# ----> 9 outfile4 = open("ClusterLib"+os.sep+"output4.txt","r");
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ClusterLib\\output4.txt'

# %%
x = []
y = []
for a in file5:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))

plt.plot(x, y, '.', color='blue');
outfile5 = open("ClusterLib"+os.sep+"output5.txt","r");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b87e30249284> in <module>
#       7
#       8 plt.plot(x, y, '.', color='blue');
# ----> 9 outfile5 = open("ClusterLib"+os.sep+"output5.txt","r");
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ClusterLib\\output5.txt'

# %%
x = []
y = []
for a in file6:
    b = a.split()
    x.append(float(b[0]))
    y.append(float(b[1]))

plt.plot(x, y, '.', color='blue');
outfile1 = open("ClusterLib"+os.sep+"output6.txt","r");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-3d946c9def87> in <module>
#       7
#       8 plt.plot(x, y, '.', color='blue');
# ----> 9 outfile1 = open("ClusterLib"+os.sep+"output6.txt","r");
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ClusterLib\\output6.txt'
